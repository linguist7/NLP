# %% [markdown]
# * 'page rank', 'text rank'에 관한 자세한 설명은 https://bab2min.tistory.com/552 참고.

# %%
import os
import pandas as pd
import numpy as np

from gensim.summarization.summarizer import summarize

# %%
! unzip /content/2020-02-019.도서자료요약_Sample.zip -d test  # AI-hub 에서 도서자료 요약 샘플 데이터 사용
# Out:
# Archive:  /content/2020-02-019.도서자료요약_Sample.zip
#   inflating: test/CNTS-00047965957_40_41-0.json
#   inflating: test/CNTS-00047966059_168.json
#   inflating: test/CNTS-00047966059_371.json
#   inflating: test/CNTS-00047966059_451.json
#   inflating: test/CNTS-00047966059_497.json
#   inflating: test/CNTS-00047966059_589.json
#   inflating: test/CNTS-00047966059_604.json
#   inflating: test/CNTS-00047966059_7.json
#   inflating: test/CNTS-00047966265_187_187-0.json
#   inflating: test/CNTS-00047966265_240_241-0.json
#   inflating: test/CNTS-00047966265_285_285-0.json
#   inflating: test/CNTS-00047966265_466_467-0.json
#   inflating: test/CNTS-00047966265_481_481-1.json
#   inflating: test/CNTS-00047966265_483_483-0.json
#   inflating: test/CNTS-00047966265_496_496-0.json
#   inflating: test/CNTS-00047966265_499_499-1.json
#   inflating: test/CNTS-00047966265_95_95-0.json
#   inflating: test/CNTS-00047966745_129_130-0.json
#   inflating: test/CNTS-00047966750_168.json
# ...

# %%
test_data_dir = "/content/test/"

test_passage_data = []
test_summary_data = []

for i in range(len(os.listdir(test_data_dir))):
    target = pd.read_json(test_data_dir+os.listdir(test_data_dir)[i])
    test_passage_data.append(target['passage'][0])
    test_summary_data.append(target['summary'][0])
    
test_data = {
    'passage': test_passage_data, 'summary': test_summary_data
}

test_df = pd.DataFrame(test_data)

test_df.to_csv("/content/Book_test.csv")

# %%
df = pd.read_csv('/content/Book_test.csv')
df.head()
# Out:
#    Unnamed: 0                                            passage  \
# 0           0  한국, 일본, 대만, 미국 및 핀란드 영유아의 평일 기상시각을 조사한 결과, 5개국...
# 1           1  그렇다면 내부 통제 시스템 등의 구비 조치가 완전하지 아니하거나, 비록 이에 대한 ...
# 2           2  병역의무 이행 후 사회적응 교육은 현재 10년 이상 장기복무 제대 군인으로 한정되어...
# 3           3  총 26명의 피면담자 10명(<표 Ⅱ-1> 중 17에서 26번 피면담자)은 기존 통...
# 4           4  5. 향후전망\n결제리스크 관리제도의 도입은 금융기관의 일중 미결제채무액을 자기능력...
#
#                                              summary
# 0  한국, 일본, 대만, 미국, 핀란드 영유아의 평일 기상시각을 조사한 결과 일본, 미...
# 1  내부 통제 시스템이 온전히 구비되지 않았거나 효율적인 운용이 이뤄지지 않았더라도 열...
# 2  제대 후 사회적응 교육은 10년 이상 장기복무자에게만 한정되어 있으며 의무복무 제대...
# 3  기존 인터뷰와 달리, 본 연구는 해외파견 노동 경험에 대해서만 인터뷰를 진행했기 때...
# 4  결제리스크 관리제도의 도입은 우리나라 지급결제제도의 안정성을 제고시키는 데에 큰 도...

# %%
df['passage'][0]
# Out:
# '한국, 일본, 대만, 미국 및 핀란드 영유아의 평일 기상시각을 조사한 결과, 5개국 영유아의 기상시각은 통계적으로 유의한 차이가 나타났다. 일본, 미국, 핀란드의 경우 7시 30분 이전에 일어나는 영유아 비율이 70%를 상회하는 것으로 나타났고, 대만의 경우 49.3%였으며, 한국은 20.4%로 나타났다. 8시 이후에 일어나는 비율은 한국의 경우 50% 이상인 반면, 대만은 18%, 핀란드는 10% 미국은 5% 정도로 낮은 비율이었다. 한국의 경우8시 30분 이후에 일어나는 비율도 10%를 넘는 것으로 나타났다. 평균 기상시각은 일본 7시 2분, 미국 7시 5분, 핀란드 7시 7분, 대만 7시 22분, 한국 7시 45분으로 한국 영유아가 가장 늦게 일어나는 것으로 조사되었다.'

# %%
for i in range(5):
  print('\n원문:', df['passage'][i], '\n요약:', summarize(df['passage'][i], ratio=0.2), '\n------------------------------------------------------------------------------------------')
# Out:
# WARNING:gensim.summarization.summarizer:Input text is expected to have at least 10 sentences.
# WARNING:gensim.summarization.summarizer:Input corpus is expected to have at least 10 documents.
# WARNING:gensim.summarization.summarizer:Input text is expected to have at least 10 sentences.
# WARNING:gensim.summarization.summarizer:Input corpus is expected to have at least 10 documents.
# WARNING:gensim.summarization.summarizer:Input text is expected to have at least 10 sentences.
# WARNING:gensim.summarization.summarizer:Input corpus is expected to have at least 10 documents.
# WARNING:gensim.summarization.summarizer:Input text is expected to have at least 10 sentences.
# WARNING:gensim.summarization.summarizer:Input corpus is expected to have at least 10 documents.
# WARNING:gensim.summarization.summarizer:Input text is expected to have at least 10 sentences.
# WARNING:gensim.summarization.summarizer:Input corpus is expected to have at least 10 documents.
# ...
